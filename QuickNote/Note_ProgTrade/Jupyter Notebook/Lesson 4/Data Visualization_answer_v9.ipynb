# %% [markdown]
# # Data visualization_v9

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [raw]
# import sys
# !{sys.executable} -m pip install yfinance

# %%
import matplotlib.pyplot as plt
import yfinance as yf

# %%
data = yf.download('^HSI','2019-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-02  25824.439453  25824.439453  25055.269531  25130.349609
# 2019-01-03  25077.679688  25262.210938  24896.869141  25064.359375
# 2019-01-04  24946.119141  25626.029297  24924.730469  25626.029297
# 2019-01-07  26015.839844  26043.640625  25753.460938  25835.699219
# 2019-01-08  25852.500000  25960.890625  25688.500000  25875.449219
#
#                Adj Close      Volume
# Date
# 2019-01-02  25130.349609  1666316400
# 2019-01-03  25064.359375  1481291700
# 2019-01-04  25626.029297  1708572100
# 2019-01-07  25835.699219  1447090300
# 2019-01-08  25875.449219  1578205700

# %%
data["Date"]=data.index

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-02  25824.439453  25824.439453  25055.269531  25130.349609
# 2019-01-03  25077.679688  25262.210938  24896.869141  25064.359375
# 2019-01-04  24946.119141  25626.029297  24924.730469  25626.029297
# 2019-01-07  26015.839844  26043.640625  25753.460938  25835.699219
# 2019-01-08  25852.500000  25960.890625  25688.500000  25875.449219
#
#                Adj Close      Volume       Date
# Date
# 2019-01-02  25130.349609  1666316400 2019-01-02
# 2019-01-03  25064.359375  1481291700 2019-01-03
# 2019-01-04  25626.029297  1708572100 2019-01-04
# 2019-01-07  25835.699219  1447090300 2019-01-07
# 2019-01-08  25875.449219  1578205700 2019-01-08

# %%
data=data[["Date","Open","High","Low","Close","Volume"]]

# %%
data.head()
# Out:
#                  Date          Open          High           Low         Close  \
# Date
# 2019-01-02 2019-01-02  25824.439453  25824.439453  25055.269531  25130.349609
# 2019-01-03 2019-01-03  25077.679688  25262.210938  24896.869141  25064.359375
# 2019-01-04 2019-01-04  24946.119141  25626.029297  24924.730469  25626.029297
# 2019-01-07 2019-01-07  26015.839844  26043.640625  25753.460938  25835.699219
# 2019-01-08 2019-01-08  25852.500000  25960.890625  25688.500000  25875.449219
#
#                 Volume
# Date
# 2019-01-02  1666316400
# 2019-01-03  1481291700
# 2019-01-04  1708572100
# 2019-01-07  1447090300
# 2019-01-08  1578205700

# %%
f1, ax = plt.subplots(figsize = (15,10))

# %%
f1, ax = plt.subplots(figsize = (15,10))
ax.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
ax.grid(True)
plt.show()

# %%
f1, ax = plt.subplots(figsize = (15,10))
ax.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
ax.plot(data["Date"],data["High"],color="red",label="High",linewidth=1)
ax.grid(True)
ax.legend()
plt.show()

# %%
f1, ax = plt.subplots(figsize = (15,10))
ax.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
ax1=ax.twinx()
ax1.plot(data["Date"],data["Volume"],color="red",label="Volume",linewidth=1)
ax.grid(True)
ax.legend()
plt.show()

# %%
f1, ax1 = plt.subplots(figsize = (15,10))
data["Close"].plot(kind="line",ax=ax1,color="black",label="Close",grid=True)
plt.show()

# %%
fig = plt.figure(figsize = (15,10))

ax1 = plt.subplot2grid((5,4), (0,0), rowspan=4, colspan=4)

ax1.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
ax1.grid(True)
ax1v = plt.subplot2grid((5,4), (4,0), sharex=ax1, rowspan=1, colspan=4)
ax1v.axes.yaxis.set_ticklabels(["Volume"])
ax1v.grid(False)
#ax1v.set_ylim(0, data["Volume"].max())
plt.setp(ax1.get_xticklabels(), visible=False)
ax1v.bar(data["Date"],data["Volume"])
plt.subplots_adjust(hspace=0)
ax1.legend(loc="upper left")

plt.show()

# %% [markdown]
# ## Exercise

# %% [raw]
# Define the return to be the difference of Close and Open.
# To generate the chart with the return and the volume as the second and third subset of the chart.

# %%
data["Return"]=data["Close"]-data["Open"]

# %%
fig = plt.figure(figsize = (15,10))

ax1 = plt.subplot2grid((4,1), (0,0), rowspan=2, colspan=1)
ax1.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
ax1.grid(True)

ax1r = plt.subplot2grid((4,1), (2,0), rowspan=1, colspan=1)
ax1r.plot(data["Date"],data["Return"],color="red",label="Return",linewidth=1)
ax1r.grid(True)

ax1v = plt.subplot2grid((4,1), (3,0), rowspan=1, colspan=1)
ax1v.axes.yaxis.set_ticklabels(["Volume"])
ax1v.grid(False)
#ax1v.set_ylim(0, data["Volume"].max())
ax1v.plot(data["Date"],data["Volume"],label="Volume")

plt.subplots_adjust(hspace=0)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1r.get_xticklabels(), visible=False)
ax1.legend(loc="upper left")
ax1r.legend(loc="upper left")
ax1v.legend(loc="upper left")

plt.show()

# %%
data["Close"].plot(kind="box",title="Distribution of close price of HSI",figsize=(15,10))
plt.show()

# %%
f1, ax = plt.subplots(figsize = (15,10))
ax.boxplot(data["Close"])
plt.show()

# %% [markdown]
# ### Another example

# %% [raw]
# To show the peak and bottom values of the close price.

# %%
data["Peak"]=data["Close"].rolling(window=20).max()
data["Bottom"]=data["Close"].rolling(window=20).min()

# %%
fig = plt.figure(figsize = (15,10))

ax1 = plt.subplot2grid((5,1), (0,0), rowspan=2, colspan=1)
ax1.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
ax1.grid(True)

ax1_peak = plt.subplot2grid((5,1), (2,0), rowspan=1, colspan=1)
ax1_peak.plot(data["Date"],data["Peak"],color="green",label="Peak",linewidth=1)
ax1_peak.grid(True)

ax1_peak.plot(data["Date"],data["Close"],color="red",label="Close",linewidth=1)

ax1_bottom = plt.subplot2grid((5,1), (3,0), rowspan=1, colspan=1)
ax1_bottom.plot(data["Date"],data["Bottom"],color="black",label="Bottom",linewidth=1)
ax1_bottom.grid(True)

ax1_bottom.plot(data["Date"],data["Close"],color="red",label="Close",linewidth=1)

ax1v = plt.subplot2grid((5,1), (4,0), rowspan=1, colspan=1)
ax1v.axes.yaxis.set_ticklabels(["Volume"])
#ax1v.grid(False)
#ax1v.set_ylim(0, data["Volume"].max())
ax1v.bar(data["Date"],data["Volume"],label="Volume")
ax2=ax1v.twinx()
ax2.plot(data["Date"],data["Close"],color="red",label="Close",linewidth=1)

plt.subplots_adjust(hspace=0)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1_peak.get_xticklabels(), visible=False)
plt.setp(ax1_bottom.get_xticklabels(), visible=False)

ax1.legend(loc="upper left")
ax1_peak.legend(loc="upper left")
ax1_bottom.legend(loc="upper left")

plt.show()

# %% [markdown]
# ## Use case: To measure the volatity of the close price

# %%
data["Close"].pct_change().rolling(window=10).std().plot(figsize=(16,4))
plt.show()

# %% [markdown]
# ## Exercise

# %% [raw]
# By using Mataplotlib generate the chart which shows the volatity of HSI, 0700.HK and 0939.HK respectively.

# %%
df_HSI=yf.download("^HSI","2019-01-01")
df_0700HK=yf.download("0700.HK","2019-01-01")
df_0939HK=yf.download("0939.HK","2019-01-01")
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(16,4))
fig.suptitle('Volatity analysis', size=20, y=1.02)
df_HSI["Close"].pct_change().rolling(window=10).std().plot(kind='line',color="black", ax=ax1,label="HSI")
df_0700HK["Close"].pct_change().rolling(window=10).std().plot(kind='line',color="red", ax=ax1,label="0700.HK")
df_0939HK["Close"].pct_change().rolling(window=10).std().plot(kind='line',color="green",ax=ax1,label="0939.HK")

ax1.legend()
plt.show()

# %% [markdown]
# ## Generate candlestick charts

# %% [raw]
# We could use candlestick_ohlc and candlestick2_ohlc for the generation of the candlestick chart

# %% [raw]
# import sys
# !{sys.executable} -m pip install https://github.com/matplotlib/mpl_finance/archive/master.zip

# %%
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates
# %matplotlib inline

# %%
ohlc= data[['Date', 'Open', 'High', 'Low','Close',"Volume"]].copy()
ohlc.head()
# Out:
#                  Date          Open          High           Low         Close  \
# Date
# 2019-01-02 2019-01-02  25824.439453  25824.439453  25055.269531  25130.349609
# 2019-01-03 2019-01-03  25077.679688  25262.210938  24896.869141  25064.359375
# 2019-01-04 2019-01-04  24946.119141  25626.029297  24924.730469  25626.029297
# 2019-01-07 2019-01-07  26015.839844  26043.640625  25753.460938  25835.699219
# 2019-01-08 2019-01-08  25852.500000  25960.890625  25688.500000  25875.449219
#
#                 Volume
# Date
# 2019-01-02  1666316400
# 2019-01-03  1481291700
# 2019-01-04  1708572100
# 2019-01-07  1447090300
# 2019-01-08  1578205700

# %%
ohlc["Date"] = ohlc["Date"].apply(mdates.date2num)

# %%
ohlc.head()
# Out:
#                 Date          Open          High           Low         Close  \
# Date
# 2019-01-02  737061.0  25824.439453  25824.439453  25055.269531  25130.349609
# 2019-01-03  737062.0  25077.679688  25262.210938  24896.869141  25064.359375
# 2019-01-04  737063.0  24946.119141  25626.029297  24924.730469  25626.029297
# 2019-01-07  737066.0  26015.839844  26043.640625  25753.460938  25835.699219
# 2019-01-08  737067.0  25852.500000  25960.890625  25688.500000  25875.449219
#
#                 Volume
# Date
# 2019-01-02  1666316400
# 2019-01-03  1481291700
# 2019-01-04  1708572100
# 2019-01-07  1447090300
# 2019-01-08  1578205700

# %%
ohlc= data[['Date', 'Open', 'High', 'Low','Close',"Volume"]].copy()
ohlc["Date"] = ohlc["Date"].apply(mdates.date2num)

# %%
f1, ax = plt.subplots(figsize = (15,10))

candlestick_ohlc(ax, ohlc.values, width=0.8, colorup='green', colordown='red')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax.grid(True)

# %% [markdown]
# ### Another example

# %%
data["Volatity"]=data["Close"].pct_change().rolling(window=10).std()

# %%
data1=data[["Date","Open","High","Low","Close","Volume","Volatity"]].loc["2019-01-01":"2019-03-01"].copy()
ohlc=data1.copy()
ohlc["Date"] = ohlc["Date"].apply(mdates.date2num)

# %%
fig = plt.figure(figsize = (15,10))

ax1 = plt.subplot2grid((4,1), (0,0), rowspan=2, colspan=1)
candlestick_ohlc(ax1, ohlc.values, width=0.8, colorup='green', colordown='red')

#ax1.plot(data["Date"],data["Close"],color="blue",label="Close",linewidth=1)
#ax1.grid(True)

ax1r = plt.subplot2grid((4,1), (2,0), rowspan=1, colspan=1)
ax1r.plot(data1["Date"],data1["Volatity"],color="red",label="Volatity",linewidth=1)
ax1r.grid(True)

ax1v = plt.subplot2grid((4,1), (3,0), rowspan=1, colspan=1)
ax1v.axes.yaxis.set_ticklabels(["Volume"])
ax1v.grid(False)
#ax1v.set_ylim(0, data["Volume"].max())
ax1v.bar(data1["Date"],data1["Volume"],label="Volume")
ax2=ax1v.twinx()
ax2.plot(data1["Date"],data1["Close"],color="red",label="Close",linewidth=1)

plt.subplots_adjust(hspace=0)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax1r.get_xticklabels(), visible=False)
#ax1.legend(loc="upper left")
ax1r.legend(loc="upper left")
ax1v.legend(loc="upper left")

plt.show()

# %%
from mpl_finance import candlestick2_ohlc

# %%
data=data.loc["2020-01-01":].copy()
f1, ax4 = plt.subplots(figsize = (15,10))

ax4.set_xticks(range(0, len(data.index), 5))
ax4.set_xticklabels(data.index[::5].strftime("%Y-%m-%d"))

candlestick2_ohlc(ax4, opens=data["Open"], highs=data["High"], lows=data["Low"], closes=data["Close"],
                  width=0.5, colorup="forestgreen", colordown="firebrick", alpha=1)
plt.xticks(rotation=90)
plt.show()

# %%
data1=data.loc["2020-01-01":].copy()
data1["ID"]=range(len(data1))
f1= plt.subplots(figsize = (15,10))

ax4 = plt.subplot2grid((3,1), (0,0), rowspan=2, colspan=1)
ax4.set_xticks(range(0, len(data1.index), 5))
ax4.set_xticklabels(data1.index[::5].strftime("%Y-%m-%d"))

candlestick2_ohlc(ax4, opens=data1["Open"], highs=data1["High"], lows=data1["Low"], closes=data1["Close"],
                  width=0.5, colorup="forestgreen", colordown="firebrick", alpha=1)
ax1v = plt.subplot2grid((3,1), (2,0), sharex=ax4, rowspan=1, colspan=1)


ax1v.axes.yaxis.set_ticklabels(["Volume"])
#ax1v.grid(False)
#ax1v.set_ylim(0, data["Volume"].max())
plt.setp(ax4.get_xticklabels(), visible=False)
ax1v.bar(data1["ID"],data1["Volume"])
plt.subplots_adjust(hspace=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Correlation analysis

# %% [markdown]
# ## Example-plotting Dollar index, gold and HSI

# %%
df_dollar=yf.download("DX-Y.NYB","2019-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_dollar.tail()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2020-06-01  98.300003  98.320000  97.790001  97.820000  97.820000       0
# 2020-06-02  97.839996  97.910004  97.430000  97.669998  97.669998       0
# 2020-06-03  97.570000  97.629997  97.190002  97.279999  97.279999       0
# 2020-06-04  97.320000  97.629997  96.570000  96.680000  96.680000       0
# 2020-06-05  96.739998  97.029999  96.440002  96.940002  96.940002       0

# %%
df_dollar["Date"]=df_dollar.index

# %%
df_gold=yf.download("GC=F","2019-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#df_gold=yf.download("2840.HK","2019-01-01")
df_gold["Date"]=df_gold.index

# %%
f1, ax = plt.subplots(figsize = (15,10))
ax.plot(data["Date"],data["Close"],color="blue",label="HSI",linewidth=1)
ax1=ax.twinx()
ax1.plot(df_dollar["Date"],df_dollar["Close"],color="red",label="Dollar",linewidth=1)
ax.grid(True)
ax.legend()
ax1.legend(loc="lower right")
plt.show()

# %%
f1, ax = plt.subplots(figsize = (15,10))
ax.plot(df_gold["Date"],df_gold["Close"],color="blue",label="Gold",linewidth=1)
ax1=ax.twinx()
ax1.plot(df_dollar["Date"],df_dollar["Close"],color="red",label="Dollar",linewidth=1)
ax.grid(True)
ax.legend()
ax1.legend(loc="lower right")
plt.show()

# %%
from scipy import stats

# %%
df_dollar.shape
# Out:
# (243, 7)

# %%
data.shape
# Out:
# (239, 7)

# %%
df_dollar.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume       Date
# Date
# 2018-12-31  96.40  96.51  96.07  96.17      96.17       0 2018-12-31
# 2019-01-02  96.14  96.96  95.82  96.82      96.82       0 2019-01-02
# 2019-01-03  96.72  96.75  96.21  96.31      96.31       0 2019-01-03
# 2019-01-04  96.28  96.61  96.05  96.19      96.19       0 2019-01-04
# 2019-01-07  96.16  96.16  95.64  95.71      95.71       0 2019-01-07

# %%
df_dollar.index.difference(data.index)
# Out:
# DatetimeIndex(['2018-12-31', '2019-02-05', '2019-02-06', '2019-02-07',
#                '2019-04-05', '2019-04-22', '2019-05-01', '2019-05-13',
#                '2019-06-07', '2019-07-01', '2019-10-01', '2019-10-07'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
data.index.difference(df_dollar.index)
# Out:
# DatetimeIndex(['2019-01-21', '2019-02-18', '2019-05-27', '2019-07-03',
#                '2019-07-04', '2019-09-02', '2019-11-28', '2019-11-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
L1=[i for i in df_dollar.index.tolist() if i not in df_dollar.index.difference(data.index)]

# %%
L2=[i for i in data.index.tolist() if i not in data.index.difference(df_dollar.index)]

# %%
data=data.loc[L2].copy()

# %%
df_dollar=df_dollar.loc[L1].copy()

# %%
stats.pearsonr(data["Close"],df_dollar["Close"])
# Out:
# (-0.36720821205068926, 8.76480004484308e-09)
